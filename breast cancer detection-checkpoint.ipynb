# %% [markdown]
# # Breast Cancer Detection

# %% [markdown]
# Let's import the necessary libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle

# %% [markdown]
# Let's have a look at the data

# %%
df = pd.read_csv(r'D:\joel\UDEMY -\datasets and codes\Notebooks\.ipynb_checkpoints\breast cancer detection\data.csv')
print (df.shape)
df.head(8)
# Out:
# (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# ...

# %% [markdown]
# The columns 'id' &'Unnamed: 32' are just index & Null value variables. Let's remove them before we go any further.

# %%
df = df.drop(['id','Unnamed: 32'],axis=1)
df.shape
# Out:
# (569, 31)

# %% [markdown]
# We can see the dataset has many variables but very few observations.

# %% [markdown]
# Let's have a look at the distribution of Benign:0 Vs Malignant:1 observations

# %%
print(df['diagnosis'].value_counts()/df.shape[0]*100)
df['diagnosis'].value_counts().plot(kind='bar')
# Out:
# B    62.741652
# M    37.258348
# Name: diagnosis, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# We can see that more than 67% of the observations are Benign & 37% are Malignant.

# %% [markdown]
# This is an imbalanced dataset, we can try to balance these observations after Outlier removal & Feature selection.

# %% [markdown]
# Let's also replace the encodings 'B' with 0 and 'M' with 1

# %%
df['diagnosis'] = df['diagnosis'].replace(['M'],1)
df['diagnosis'] = df['diagnosis'].replace(['B'],0)
print((df['diagnosis'].value_counts()/df.shape[0])*100)
# Out:
# 0    62.741652
# 1    37.258348
# Name: diagnosis, dtype: float64

# %% [markdown]
# Let's remove the Outlier then.

# %% [markdown]
# ### Outlier Removal

# %%
for i in df.columns[1:]:
    q25,q75 = np.percentile(df[i],[25,75])
    iqr = q75 - q25
    maximum = q75 + (iqr*1.5)
    minimum = q25 - (iqr*1.5)
    df.loc[df[i]>maximum,i]= np.NaN
    df.loc[df[i]<minimum,i]= np.NaN

# %% [markdown]
# Check for missing values after Outlier-removal

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# diagnosis                   0.000000
# radius_mean                 2.460457
# texture_mean                1.230228
# perimeter_mean              2.284710
# area_mean                   4.393673
# smoothness_mean             1.054482
# compactness_mean            2.811951
# concavity_mean              3.163445
# concave points_mean         1.757469
# symmetry_mean               2.636204
# fractal_dimension_mean      2.636204
# radius_se                   6.678383
# texture_se                  3.514938
# perimeter_se                6.678383
# area_se                    11.423550
# smoothness_se               5.272408
# compactness_se              4.920914
# concavity_se                3.866432
# concave points_se           3.339192
# symmetry_se                 4.745167
# fractal_dimension_se        4.920914
# radius_worst                2.987698
# texture_worst               0.878735
# perimeter_worst             2.636204
# area_worst                  6.151142
# ...

# %% [markdown]
# There are many missing values after Outlier removal, let's impute them

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3)
df_array = np.array(df)
df = pd.DataFrame(data = imputer.fit_transform(df_array),columns = df.columns)
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# Let's look at the distribution of the independent continuous variables

# %% [markdown]
# ### Data Visualization

# %%
for col in df.columns[1:]:
    sns.distplot(df[col],norm_hist=True,color='blue',kde_kws={'label':'KDE'}) # histogram with the kernel-distribution line.
    plt.axvline(df[col].mean(), color = 'r', linestyle = 'dashed', linewidth = 2) # plotting mean line
    plt.axvline(df[col].median(),color='b',linewidth=2) # plotting median line
    plt.show()

# %% [markdown]
# In almost every variable, the mean & median are close, even coinciding in some. The Outlier removal must have helped so.

# %% [markdown]
# Let's perform Feature selection techniques over the independent variables w.r.t target 'diagnosis'

# %% [markdown]
# ### ANOVA test

# %% [markdown]
# let's perform ANOVA (analysis of Variance) test between the categorical-target and the independent numeric variables

# %%
related=[]
unrelated =[]#  list of variables  not-related to the target

from scipy import stats
for i in df.columns[1:]:
    fStat, pVal = stats.f_oneway(df['diagnosis'], df[i])
    #print(i,' P-value: ',pVal,' f-statistic: ',fStat)
    if pVal<0.05:
        related.append(i)
    else:
        unrelated.append(i)    
        
print ('related:',related) 
print ('unrelated:',unrelated)
# Out:
# related: ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']
# unrelated: ['radius_se']

# %% [markdown]
# ANOVA test says only 'radius_se' variable is not related to the target 'diagnosis'

# %% [markdown]
# ### ExtraTrees Classifier

# %% [markdown]
# it uses a tree-based classifiers approach

# %%
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.ensemble import ExtraTreesClassifier

# on the red wine dataset
X = df.iloc[:,1:]
y = df['diagnosis']
Importances = ExtraTreesClassifier().fit(X,y)
#print (redImportances.feature_importances_)

# Let's look at the scores visually

print ('Extra trees- feature importance')
Values = pd.Series(Importances.feature_importances_, index = df.columns[1:])
Values.nlargest(df.shape[1]-1).plot(kind='bar')
plt.figsize=(10,15)
plt.show()
# Out:
# Extra trees- feature importance

# %% [markdown]
# Extra trees classifier too shows importances of different variables in varying proportions.

# %% [markdown]
# Let's make a list of the least 15 important variables which we can see in the graph towards the right and compare them later with
# other test's unimportant features

# %%
ET_unimportant = list(Values.nsmallest(15).index)

# %% [markdown]
# ### Logistic regression feature importance

# %%
# let's perform both tests on red wine first
# source: https://towardsdatascience.com/feature-selection-using-regularisation-a3678b71e499
from sklearn.linear_model import Lasso, LogisticRegression # Lasso is L1 regularization
from sklearn.feature_selection import SelectFromModel

# fitting the feature selection model with the Logistic regression data
sel_ = SelectFromModel(LogisticRegression(C=1, penalty='l2'))
sel_.fit(X,y)


# Visualising features that were kept by the lasso regularisation
print (sel_.get_support())

#  So True is for the features that lasso thought is important (non-zero features) 
# while False is for the features whose weights were shrinked to zero and are not important according to Lasso.


selected_feat = X.columns[(sel_.get_support())] # gives the remaining features
LR_unimportant=[i for i in df.columns[1:] if i not in selected_feat]

print ('important: ',selected_feat)
print ('unimportant: ',LR_unimportant)
# Out:
# [ True  True  True False False False  True False False False False False
#  False False False False False False False False  True  True  True False
#  False  True  True  True False False]
# important:  Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'concavity_mean',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'compactness_worst',
#        'concavity_worst', 'concave points_worst'],
#       dtype='object')
# unimportant:  ['area_mean', 'smoothness_mean', 'compactness_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'area_worst', 'smoothness_worst', 'symmetry_worst', 'fractal_dimension_worst']
# c:\python37\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %% [markdown]
# Logistic regression feature importance shows many variables are present that are unimportant

# %% [markdown]
# ### Random Forest Feature importance

# %%
from sklearn.ensemble import RandomForestClassifier
sel_ = SelectFromModel(RandomForestClassifier())

sel_.fit(X, y)


print (sel_.get_support())
selected_feat = X.columns[(sel_.get_support())] # gives the remaining features
print ('Random-forest features selected: ')
print (selected_feat)
RF_unimportant = [c for c in df.columns[1:] if c not in selected_feat]
print ('Random forest\'s not important features: ')
print (RF_unimportant)
# Out:
# [False False  True False False False  True  True False False False False
#  False False False False False False False False  True False  True  True
#  False False False  True False False]
# Random-forest features selected:
# Index(['perimeter_mean', 'concavity_mean', 'concave points_mean',
#        'radius_worst', 'perimeter_worst', 'area_worst',
#        'concave points_worst'],
#       dtype='object')
# Random forest's not important features:
# ['radius_mean', 'texture_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'texture_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %% [markdown]
# Random Forest feature importance also says many variables are present that are unimportant.

# %% [markdown]
# Let's remove the unimportant variables common in Logistic regression, Extratrees classifier & Random forest feature importance test

# %%
len(LR_unimportant),len(RF_unimportant),len(ET_unimportant)
# Out:
# (20, 23, 15)

# %% [markdown]
# Since Extra trees classifier has the least unimportant variables, let's see what is common among others and it.

# %%
drop_list = [i for i in ET_unimportant if i in LR_unimportant and RF_unimportant]+['radius_se'] # radius_se is common in 3 tests

# %%
len(drop_list)
# Out:
# 15

# %% [markdown]
# These 15 variables will be dropped, creating a new dataframe.

# %%
df2 = df.drop(drop_list, axis=1)
print (df2.shape)
df2.head()
# Out:
# (569, 16)
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        1.0        17.99         10.38          122.80     1001.0
# 1        1.0        20.57         17.77          132.90     1326.0
# 2        1.0        19.69         21.25          130.00     1203.0
# 3        1.0        11.42         20.38           77.58      386.1
# 4        1.0        20.29         14.34          135.10     1297.0
#
#    concavity_mean  concave points_mean  perimeter_se    area_se  radius_worst  \
# 0        0.178433              0.14710      4.847333  80.690000         25.38
# 1        0.086900              0.07017      3.398000  74.080000         24.99
# 2        0.197400              0.12790      4.585000  79.966667         23.57
# 3        0.241400              0.10520      3.445000  27.230000         14.91
# 4        0.198000              0.10430      5.438000  79.966667         22.54
#
#    texture_worst  perimeter_worst   area_worst  compactness_worst  \
# ...

# %% [markdown]
# Let's have a look at the correlation heatmap of independent continuous variables.

# %% [markdown]
# ### Correlation Heatmap

# %%
corr = df2.drop('diagnosis',axis=1).corr()
f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), 
            cmap=sns.diverging_palette(220, 50, as_cmap=True),
            square=True, ax=ax,annot = True)
plt.show()

# %% [markdown]
# We can see radius_mean is correlated with many variables: perimeter_mean, area_mean, concave_points_mean, area_se, radius_worst, perimeter_worst,area_worst

# %% [markdown]
# But Multicollinearity doesn't affect the prediction quality of the models, we shall keep all these variables.

# %% [markdown]
# Let's normalize the continuous variables between 0 and 1

# %% [markdown]
# ### Feature Normalization

# %%
for c in df2.columns[1:]:
    df2[c] = (df2[c]-min(df2[c]))/(max(df2[c])-min(df2[c]))
    print (c,': ',min(df2[c]),max(df2[c]))
    
df2.head()
# Out:
# radius_mean :  0.0 1.0
# texture_mean :  0.0 1.0
# perimeter_mean :  0.0 1.0
# area_mean :  0.0 1.0
# concavity_mean :  0.0 1.0
# concave points_mean :  0.0 1.0
# perimeter_se :  0.0 1.0
# area_se :  0.0 1.0
# radius_worst :  0.0 1.0
# texture_worst :  0.0 1.0
# perimeter_worst :  0.0 1.0
# area_worst :  0.0 1.0
# compactness_worst :  0.0 1.0
# concavity_worst :  0.0 1.0
# concave points_worst :  0.0 1.0
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        1.0     0.745413      0.033070        0.763308   0.725159
# 1        1.0     0.920103      0.397828        0.860883   1.000000
# 2        1.0     0.860519      0.569595        0.832866   0.895983
# 3        1.0     0.300562      0.526654        0.326442   0.205159
# 4        1.0     0.901144      0.228529        0.882137   0.975476
#
#    concavity_mean  concave points_mean  perimeter_se   area_se  radius_worst  \
# 0        0.634994             0.967763      0.800770  0.963363      0.899948
# ...

# %% [markdown]
# Let's split the data into train & test.

# %%
from sklearn.model_selection import train_test_split
from collections import Counter

X = df2.iloc[:,1:]
y = df2['diagnosis']

# Let's split the data into train & test before oversampling the training data
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7)
print ('Training shape: ',X_train.shape,y_train.shape)
print ('Testing shape: ',X_test.shape,y_test.shape)
print ('Ratio of 1 & 0 in ytest:',Counter(y_test))
# Out:
# Training shape:  (398, 15) (398,)
# Testing shape:  (171, 15) (171,)
# Ratio of 1 & 0 in ytest: Counter({0.0: 105, 1.0: 66})

# %% [markdown]
# As we saw earlier, the count of malignant 1 observations is very low compared to benign cases 0, we need to balance the dataset.
# Also we need to oversample the training data after balancing so that model has enough observations to train properly.

# %%
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler(1)
X_train_os,y_train_os = os.fit_sample(X_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_os)))
print ('New training data shape: ',X_train_os.shape,y_train_os.shape)
# Out:
# The number of classes before fit Counter({0.0: 252, 1.0: 146})
# The number of classes after fit Counter({0.0: 252, 1.0: 252})
# New training data shape:  (504, 15) (504,)
# c:\python37\lib\site-packages\imblearn\utils\_validation.py:638: FutureWarning: Pass sampling_strategy=1 as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   FutureWarning)

# %% [markdown]
# Let's oversample the data 4 times and look at it's shape

# %%
X0 = np.array(X_train_os[y_train_os==0])
X1 = np.array(X_train_os[y_train_os==1])
X = np.vstack([X0, X0, X0, X0, X1, X1, X1, X1])
Y = np.concatenate(([0]*4*len(X0), [1]*4*len(X1)))
X,Y = shuffle(X,Y)
X.shape,Y.shape
# Out:
# ((2016, 15), (2016,))

# %% [markdown]
# Let's define an error-metric function to judge the model's classifications

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

def error_metric(y_true,y_preds):
    CM = pd.crosstab(y_true,y_preds) # the confusion matrix
    TN = CM.iloc[0,0]
    FN = CM.iloc[1,0]
    TP = CM.iloc[1,1]
    FP = CM.iloc[0,1]
    print (classification_report(y_true, y_preds))
    print (confusion_matrix(y_true,y_preds))
    print ('accuracy score: ',accuracy_score(y_true, y_preds)*100,'%') #check accuracy of model
    print ('False-Negative-Rate: ',(FN*100)/(FN+TP),'%') #False Negative rate 
    print ('true-positive-rate: ',((TP)*100)/(TP+FN),'%')

# %% [markdown]
# Let's also define a function to plot the AUC-ROC curve

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from matplotlib import pyplot as plt
def plotRocAuc(fpr, tpr, thresholds,score):
       
    # Plot the "dumb model" line
    plt.plot([0, 1], [0, 1], linestyle='--')
    
    # Plot the model line
    plt.plot(fpr, tpr, marker='.')
    plt.text(0.75, 0.25, "AUC: " + str(round(score,2)))
    
    # show the plot
    plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR_model = LogisticRegression().fit(X,Y) 
LR_preds = LR_model.predict_proba(X_test)
print (error_metric(y_test,np.round((LR_preds)[:,1])))
LR_fpr,LR_tpr,LR_thresholds = roc_curve(y_test,LR_preds[:,1])
LR_score = roc_auc_score(y_test, LR_preds[:,1])
plotRocAuc(LR_fpr, LR_tpr, LR_thresholds,LR_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95       105
#          1.0       0.92      0.92      0.92        66
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171
#
# [[100   5]
#  [  5  61]]
# accuracy score:  94.15204678362574 %
# False-Negative-Rate:  7.575757575757576 %
# true-positive-rate:  92.42424242424242 %
# None

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
DT_model = DecisionTreeClassifier(criterion='entropy').fit(X,Y)
DT_preds = DT_model.predict_proba(X_test)
print(error_metric(y_test,np.round(DT_preds[:,1])))
DT_fpr, DT_tpr, DT_thresholds = roc_curve(y_test, DT_preds[:,1])
DT_score = roc_auc_score(y_test, DT_preds[:,1])
plotRocAuc(DT_fpr, DT_tpr, DT_thresholds,DT_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.90      0.92       105
#          1.0       0.86      0.89      0.87        66
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.90      0.90       171
# weighted avg       0.90      0.90      0.90       171
#
# [[95 10]
#  [ 7 59]]
# accuracy score:  90.05847953216374 %
# False-Negative-Rate:  10.606060606060606 %
# true-positive-rate:  89.39393939393939 %
# None

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators=100).fit(X,Y)
RF_preds = RF_model.predict_proba(X_test)
error_metric(y_test,np.round(RF_preds[:,1]))
RF_fpr,RF_tpr,RF_thresholds = roc_curve(y_test,RF_preds[:,1])
RF_score = roc_auc_score(y_test, RF_preds[:,1])
plotRocAuc(RF_fpr, RF_tpr, RF_thresholds, RF_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.96      0.95       105
#          1.0       0.94      0.89      0.91        66
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.93      0.93       171
# weighted avg       0.94      0.94      0.94       171
#
# [[101   4]
#  [  7  59]]
# accuracy score:  93.56725146198829 %
# False-Negative-Rate:  10.606060606060606 %
# true-positive-rate:  89.39393939393939 %

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
NB_model = GaussianNB().fit(X,Y)
NB_preds = NB_model.predict_proba(X_test)
print (error_metric(y_test,np.round((NB_preds)[:,1])))
NB_fpr,NB_tpr,NB_thresholds = roc_curve(y_test,NB_preds[:,1])
NB_score = roc_auc_score(y_test, NB_preds[:,1])
plotRocAuc(NB_fpr, NB_tpr, NB_thresholds, NB_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95       105
#          1.0       0.92      0.92      0.92        66
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171
#
# [[100   5]
#  [  5  61]]
# accuracy score:  94.15204678362574 %
# False-Negative-Rate:  7.575757575757576 %
# true-positive-rate:  92.42424242424242 %
# None

# %% [markdown]
# ### K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
K_model = KNeighborsClassifier(n_neighbors=5).fit(X,Y)
K_preds = K_model.predict_proba(X_test)
print (error_metric(y_test,np.round((K_preds)[:,1])))
K_fpr,K_tpr,K_thresholds = roc_curve(y_test,K_preds[:,1])
K_score = roc_auc_score(y_test, K_preds[:,1])
plotRocAuc(K_fpr, K_tpr, K_thresholds, K_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.94      0.94       105
#          1.0       0.91      0.89      0.90        66
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.92      0.92       171
# weighted avg       0.92      0.92      0.92       171
#
# [[99  6]
#  [ 7 59]]
# accuracy score:  92.39766081871345 %
# False-Negative-Rate:  10.606060606060606 %
# true-positive-rate:  89.39393939393939 %
# None

# %% [markdown]
# ### AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_classifier=AdaBoostClassifier().fit(X,Y)
ADA_preds = ada_classifier.predict_proba(X_test)
ADA_fpr, ADA_tpr, ADA_thresholds = roc_curve(y_test, ADA_preds[:,1])
ADA_score = roc_auc_score(y_test, ADA_preds[:,1])
error_metric(y_test,np.round(ADA_preds[:,1]))
plotRocAuc(ADA_fpr, ADA_tpr, ADA_thresholds, ADA_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94       105
#          1.0       0.95      0.86      0.90        66
#
#     accuracy                           0.93       171
#    macro avg       0.93      0.92      0.92       171
# weighted avg       0.93      0.93      0.93       171
#
# [[102   3]
#  [  9  57]]
# accuracy score:  92.98245614035088 %
# False-Negative-Rate:  13.636363636363637 %
# true-positive-rate:  86.36363636363636 %

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC
SV_model = SVC(C=1.0,probability=True).fit(X,Y)
SV_preds = SV_model.predict_proba(X_test)

SV_fpr, SV_tpr, SV_thresholds = roc_curve(y_test, SV_preds[:,1])
SV_score = roc_auc_score(y_test, SV_preds[:,1])
error_metric(y_test,np.round(SV_preds[:,1]))
plotRocAuc(SV_fpr, SV_tpr, SV_thresholds, SV_score)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.96       105
#          1.0       0.91      0.95      0.93        66
#
#     accuracy                           0.95       171
#    macro avg       0.94      0.95      0.94       171
# weighted avg       0.95      0.95      0.95       171
#
# [[99  6]
#  [ 3 63]]
# accuracy score:  94.73684210526315 %
# False-Negative-Rate:  4.545454545454546 %
# true-positive-rate:  95.45454545454545 %

# %% [markdown]
# ### Neural Network

# %%
from keras import models
from keras import layers

def build_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='sigmoid', input_shape=(X.shape[1],)))
    model.add(layers.Dense(64, activation='sigmoid'))
    model.add(layers.Dense(1, activation='sigmoid')) # because of multi-class labels
    # defining the optimizer and loss and accuracy parameters
    model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
    return model

# testing how the individual model with sampLe parameters scores on test data
X_train_os2, x_val, y_train_os2, y_val = train_test_split(X,Y,train_size=0.7)
print (X_train_os2.shape, y_train_os2.shape)
print (x_val.shape,y_val.shape)
model = build_model()
history = model.fit(X_train_os2, y_train_os2, batch_size=64, epochs=5, validation_data=(x_val, y_val))

DL_preds = model.predict_proba(X_test)
print (DL_preds.shape)
test_results = model.evaluate(X_test,y_test)
for i in range(len(test_results)):
    print (model.metrics_names[i],': ',test_results[i])

DL_preds2 = [round(i[0]) for i in DL_preds]


import matplotlib.pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

DL_fpr, DL_tpr, DL_thresholds = roc_curve(y_test, DL_preds)
DL_score = roc_auc_score(y_test, DL_preds)
error_metric(y_test,np.array(DL_preds2))
plotRocAuc(DL_fpr, DL_tpr, DL_thresholds, DL_score)
# Out:
# (1411, 15) (1411,)
# (605, 15) (605,)
# Epoch 1/5
# 23/23 [==============================] - 1s 26ms/step - loss: 0.6726 - accuracy: 0.6258 - val_loss: 0.6478 - val_accuracy: 0.5207
# Epoch 2/5
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6296 - accuracy: 0.8462 - val_loss: 0.6126 - val_accuracy: 0.6810
# Epoch 3/5
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5782 - accuracy: 0.9043 - val_loss: 0.5433 - val_accuracy: 0.8694
# Epoch 4/5
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5085 - accuracy: 0.9327 - val_loss: 0.4803 - val_accuracy: 0.8281
# Epoch 5/5
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4320 - accuracy: 0.9383 - val_loss: 0.4004 - val_accuracy: 0.8909
# WARNING:tensorflow:From <ipython-input-71-80692e7c5ab1>:20: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# ...

# %% [markdown]
# From all the models giving predictions, thes models gave the best following error metrics (especially on the FNR)
#
#                  Logistic-Regression      SVC         DNN
# accuracy_score     94.15                 94.73       86.54
# FNR                 7.57                  4.54        1.51
# TPR                92.42                 95.45       98.48

# %% [markdown]
# In Breats Cancer Detection, our priority is that no observations which is actually positive(malign) should ever be incorrectly classified as Negative(benign).
# So the ideal model should be one with lowest FNR(recall), that is highest TPR.
# Our Deep-learning model gives the lowest FNR: 1.5% with highest TPR: 98.48%, though other models give better accuracy.

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# ##### Deep-learning model is the best for Breast Cancer Detection problem
